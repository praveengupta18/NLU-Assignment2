# %%
import nltk
from nltk.corpus import gutenberg
import tensorflow as tf
import numpy as np

# %%
guten = gutenberg.sents()

# %%
from sklearn.model_selection import train_test_split

gt_train,gt_test = train_test_split(list(guten),test_size=0.2,random_state=1)

gt_dev,gt_test = train_test_split(gt_test,test_size=0.5,random_state=1)

# %% [markdown]
# ## Data clean

# %%
def list_of_words(train):
    seq = []
    for i in range(len(train)):
        sen = [w.lower() for w in train[i] if w not in [':','/',';','|',"''",'``','(',')','-','--','_','"',',','?'] if w.isalpha()]
        seq += sen
    
    return seq

# %%
def sequences_from_list(data):
    length = 5 + 1          # chnage this 5 to 50
    sequences = list()
    for i in range(length, len(data)):
        seq = data[i-length:i]
        line = ' '.join(seq)
        sequences.append(line)
    print('Total Sequences: %d' % len(sequences))
    return sequences

# %%
# out_filename = 'republic_sequences.txt'
# save_doc(sequences, out_filename)

# %% [markdown]
# ## Neural Language Model

# %%
from numpy import array
from pickle import dump
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding

# %%
ls = list_of_words(gt_train[5:6])
print(len(ls))
# Out:
# 14

# %%
sequences = sequences_from_list(ls)
seq2 = sequences_from_list(ls)
# Out:
# Total Sequences: 8
# Total Sequences: 8

# %%
#give unique number to each word
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sequences)
sequences = tokenizer.texts_to_sequences(sequences)

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)
seq_length = X.shape[1]

# %%
# define model
# model = Sequential()
# model.add(Embedding(vocab_size, 50, input_length=seq_length))    # 50 is the embedding size
# model.add(LSTM(100, return_sequences=True))                     #100 is neurons in hidden layer
# model.add(LSTM(100))                                         #2 hidden layer
# model.add(Dense(100, activation='relu'))                       # connected to a dense layer of 100 neurons
# model.add(Dense(vocab_size, activation='softmax'))             
# print(model.summary())

# %%
model = Sequential()
model.add(Embedding(vocab_size, 4, input_length=seq_length))
model.add(LSTM(3, return_sequences=True))
model.add(LSTM(3))
model.add(Dense(3, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 5, 4)              56
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 3)              96
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 3)                 84
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 14)                56
# =================================================================
# Total params: 304
# Trainable params: 304
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# # compile model
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# # fit model
# model.fit(X, y, batch_size=128, epochs=100)

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
model.fit(X, y, batch_size=20, epochs=200)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 238ms/step - loss: 1.4093 - acc: 0.5000
# Epoch 2/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.4078 - acc: 0.5000
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4057 - acc: 0.5000
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4036 - acc: 0.5000
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4017 - acc: 0.5000
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4001 - acc: 0.5000
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3983 - acc: 0.5000
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3963 - acc: 0.5000
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3945 - acc: 0.5000
# Epoch 10/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3928 - acc: 0.5000
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3910 - acc: 0.5000
# Epoch 12/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.3892 - acc: 0.5000
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3875 - acc: 0.5000
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3857 - acc: 0.5000
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3840 - acc: 0.5000
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3821 - acc: 0.5000
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3803 - acc: 0.5000
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3785 - acc: 0.5000
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3767 - acc: 0.5000
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3749 - acc: 0.5000
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3731 - acc: 0.5000
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3713 - acc: 0.5000
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3695 - acc: 0.5000
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3677 - acc: 0.5000
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3659 - acc: 0.5000
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3642 - acc: 0.5000
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3624 - acc: 0.5000
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3606 - acc: 0.5000
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3588 - acc: 0.5000
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3570 - acc: 0.5000
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3553 - acc: 0.5000
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3535 - acc: 0.5000
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3516 - acc: 0.5000
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3498 - acc: 0.5000
# Epoch 35/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3480 - acc: 0.5000
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3463 - acc: 0.5000
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3444 - acc: 0.5000
# Epoch 38/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3426 - acc: 0.5000
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3409 - acc: 0.5000
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.
200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1823 - acc: 0.5000
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1805 - acc: 0.5000
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1787 - acc: 0.5000
# Epoch 133/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1770 - acc: 0.5000
# Epoch 134/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1753 - acc: 0.5000
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1737 - acc: 0.5000
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1719 - acc: 0.5000
# Epoch 137/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1702 - acc: 0.5000
# Epoch 138/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1684 - acc: 0.5000
# Epoch 139/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1666 - acc: 0.5000
# Epoch 140/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1650 - acc: 0.5000
# Epoch 141/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1634 - acc: 0.5000
# Epoch 142/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1616 - acc: 0.5000
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1599 - acc: 0.5000
# Epoch 144/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1581 - acc: 0.5000
# Epoch 145/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1564 - acc: 0.5000
# Epoch 146/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1547 - acc: 0.5000
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1530 - acc: 0.5000
# Epoch 148/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1513 - acc: 0.5000
# Epoch 149/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1495 - acc: 0.5000
# Epoch 150/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1479 - acc: 0.5000
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1462 - acc: 0.5000
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1445 - acc: 0.5000
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1427 - acc: 0.5000
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1410 - acc: 0.5000
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1393 - acc: 0.5000
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1376 - acc: 0.5000
# Epoch 157/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1359 - acc: 0.5000
# Epoch 158/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1342 - acc: 0.5000
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1325 - acc: 0.5000
# Epoch 160/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1308 - acc: 0.5000
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1291 - acc: 0.5000
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1275 - acc: 0.5000
# Epoch 163/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1257 - acc: 0.5000
# Epoch 164/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1240 - acc: 0.5000
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1223 - acc: 0.5000
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1206 - acc: 0.5000
# Epoch 167/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1190 - acc: 0.5000
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1172 - acc: 0.5000
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1155 - acc: 0.5000
# Epoch 170/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1138 - acc: 0.5000
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1121 - acc: 0.5000
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1105 - acc: 0.5000
# Epoch 173/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1088 - acc: 0.5000
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1070 - acc: 0.5000
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1053 - acc: 0.5000
# Epoch 176/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1036 - acc: 0.5000
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1019 - acc: 0.5000
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1002 - acc: 0.5000
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0985 - acc: 0.5000
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0968 - acc: 0.5000
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0951 - acc: 0.5000
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0934 - acc: 0.5000
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0917 - acc: 0.5000
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0900 - acc: 0.5000
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0883 - acc: 0.5000
# Epoch 186/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0866 - acc: 0.5000
# Epoch 187/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0850 - acc: 0.5000
# Epoch 188/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0833 - acc: 0.5000
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0816 - acc: 0.5000
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0798 - acc: 0.5000
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0781 - acc: 0.5000
# Epoch 192/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0765 - acc: 0.5000
# Epoch 193/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0748 - acc: 0.5000
# Epoch 194/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0731 - acc: 0.5000
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0714 - acc: 0.5000
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0697 - acc: 0.5000
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0680 - acc: 0.5000
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0663 - acc: 0.5000
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0646 - acc: 0.5000
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0629 - acc: 0.5000

# %%
# save the model to file
model.save('model.h5')
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-162-ae8f86de54c6> in <module>()
#       1 # save the model to file
# ----> 2 model.save('model.h5')
#       3 # save the tokenizer
#       4 dump(tokenizer, open('tokenizer.pkl', 'wb'))
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/topology.py in save(self, filepath, overwrite, include_optimizer)
#    2578         """
#    2579         from ..models import save_model
# -> 2580         save_model(self, filepath, overwrite, include_optimizer)
#    2581
#    2582     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.5/dist-packages/keras/models.py in save_model(model, filepath, overwrite, include_optimizer)
#      58
#      59     if h5py is None:
# ---> 60         raise ImportError('`save_model` requires h5py.')
#      61
#      62     def get_json_type(obj):
#
# ImportError: `save_model` requires h5py.

# %%
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

 
# generate a sequence from a language model
def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
    result = list()
    in_text = seed_text
    # generate a fixed number of words
    for _ in range(n_words):
        # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # predict probabilities for each word
        yhat = model.predict_classes(encoded, verbose=0)
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        # append to input
        in_text += ' ' + out_word
        result.append(out_word)
    return ' '.join(result)
 
# select a seed text
seed_text = seq2[randint(0,len(seq2)-1)]
print(seed_text + '\n')
 
# generate new text
generated = generate_seq(model, tokenizer, seq_length, seed_text, 5)
print(generated)
# Out:
# is a long game said the
#
# secretary frowned frowned frowned his
